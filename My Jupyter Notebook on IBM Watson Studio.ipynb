# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  **Sai Pradeep Penugonda
#  Design Engineer**

# %% [markdown]
# I am interested in data science because every industry wants
# to problem solving for bulk works. This Data Science uses to
# solve that issues.

# %% [markdown]
# ### My code will be executed and must display an output of 2+2

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# | Share | Price |
# | ------ | ------ |
# | Apple | 154usd |
# | Netflix | 220usd |
#
# For more details
# <a href="https://finance.yahoo.com/quote/NFLX/?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAGgnOzAqsDFH1A4STLgyzTYq4s4kSCqT34ssuDQyjjRio1c-HpQCD_udZASrBZvCuFYyQNPK2jgfPde7kZ6kAsCKUTrzO4c7Bc4jfelfa5-Bc7tp1Q14hMhAlUCDy7aox_rAKQDs4wuC3cPMGL_EgiH1TNZXFYQ47tX90Orm_skv">Yahoo Finance</a>
